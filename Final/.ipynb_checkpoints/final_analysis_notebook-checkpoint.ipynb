# %%
# Modules
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
import scipy.stats
import seaborn as sns
import os
import re
import string
import statsmodels.api as sm

# %%
# Read final data csv into df
final_df = pd.read_csv('../Final/raw_data/final merged data.csv')

final_df
# Out:
#     Unnamed: 0  Median Age  Median Household Income  Population  \
# 0            0        38.5                 101883.0     67958.0
# 1            1        35.8                 146422.0     87319.0
# 2            2        33.8                 220173.0    105120.0
# 3            3        36.6                 228168.0     70176.0
# 4            4        38.0                 324337.0     72514.0
# 5            5        37.4                1117072.0    112102.0
# 6            6        35.5                 136904.0     49879.0
# 7            7        37.8                 314878.0     61438.0
# 8            8        35.1                 338916.0    123966.0
# 9            9        32.7                 181362.0     51000.0
# 10          10        29.9                 244745.0     44150.0
# 11          11        33.7                 428772.0     98514.0
# 12          12        32.6                 211063.0     41331.0
# 13          13        36.6                 126200.0     78505.0
# 14          14        34.7                 134672.0     98721.0
# 15          15        34.9                 445623.0     67001.0
#
#                              Locale  Violent Crime Total  \
# 0        Albemarle County, Virginia                   97
# 1         Alexandria city, Virginia                  280
# 2        Arlington County, Virginia                  314
# 3         Chesapeake city, Virginia                  999
# 4     Chesterfield County, Virginia                  422
# 5          Fairfax County, Virginia                  969
# 6            Hampton city, Virginia                  349
# 7          Henrico County, Virginia                  502
# 8          Loudoun County, Virginia                  221
# 9       Newport News city, Virginia                  782
# 10           Norfolk city, Virginia                 1285
# 11  Prince William County, Virginia                  773
# 12          Richmond city, Virginia                 1264
# 13    Spotsylvania County, Virginia                  213
# 14        Stafford County, Virginia                  243
# 15    Virginia Beach city, Virginia                  667
#
#     Property Crime Total  Violent Rate  Property Rate  Walk Score  \
# 0                   1604      0.001427       0.023603        5.32
# 1                   2983      0.003207       0.034162       52.59
# 2                   3521      0.002987       0.033495       62.63
# 3                   6429      0.014236       0.091613        3.63
# 4                   6373      0.005820       0.087886        7.99
# 5                  14603      0.008644       0.130265       54.82
# 6                   4441      0.006997       0.089035       30.15
# 7                   7818      0.008171       0.127250       16.43
# 8                   2607      0.001783       0.021030        3.38
# 9                   5552      0.015333       0.108863       27.54
# 10                  9696      0.029105       0.219615       37.43
# 11                  5901      0.007847       0.059900       26.06
# 12                  8426      0.030582       0.203866       33.37
# 13                  1975      0.002713       0.025158        0.91
# 14                  2111      0.002461       0.021383        5.52
# 15                  9865      0.009955       0.147237        7.33
#
#     Population Density
# 0           144.962534
# 1         10005.381352
# 2          8730.032197
# 3           684.803983
# 4           785.356713
# 5          2910.082967
# 6          2660.875061
# 7          1377.525769
# 8           703.918424
# 9          2657.263510
# 10         4537.793761
# 11         1326.058689
# 12         3641.594616
# 13          321.767955
# 14          520.601627
# 15         1805.987001

# %%
scipy.stats.linregress(final_df['Walk Score'], final_df['Population Density'].astype(float))
# Out:
# LinregressResult(slope=121.78521780347289, intercept=-179.22681497391704, rvalue=0.85277245038292748, pvalue=2.6993943658670418e-05, stderr=19.934391435047633)

# %%
# Build scatter plot population density vs. walk score
fig, ax = plt.subplots(figsize=(15, 10))


final_df['Population Density'] = round(final_df['Population Density'].astype(float), 2)

#for i in range(len(final_df['Locale'])):
ax.scatter(final_df['Walk Score'], final_df['Population Density'],
           edgecolor="k", linewidths=1, marker="o", s=100, label=final_df['Locale'],
           alpha=0.8, c='c')

for i,text in enumerate(final_df['Locale']):
    ax.annotate(i, (final_df['Walk Score'][i]+0.01, final_df['Population Density'][i]+100))


# format graph 
sns.set_style('darkgrid')
plt.xlim([0, 65])
plt.ylim([0, 10500])

plt.xlabel('Walk Score', fontsize=16)
plt.ylabel('Population Density (per sq. Mile)', fontsize=16)
plt.title('Population Density vs. Walk Score', fontsize=20)

plt.legend(loc=2, frameon=True)

# save figure
plt.savefig('output/popdens_v_walkscore.png')

# show plot
plt.show()

# %%
# Build scatter plot population density vs. Violent Crime Rate
fig, ax = plt.subplots(figsize=(15, 10))


final_df['Population Density'] = round(final_df['Population Density'].astype(float), 2)

ax.scatter(final_df['Violent Rate'], final_df['Population Density'],
           edgecolor="k", linewidths=1, marker="o", s=100, label=final_df['Locale'],
           c='c', alpha=0.8)

for i,text in enumerate(final_df['Locale']):
    ax.annotate(i, (final_df['Violent Rate'][i]+0.0001, final_df['Population Density'][i]+120))

# format graph 
sns.set_style('darkgrid')
plt.xlim([0, 0.035])
plt.ylim([0, 10500])

plt.xlabel('Per Capita Violent Crime Rate', fontsize=16)
plt.ylabel('Population Density (per sq. Mile)', fontsize=16)
plt.title('Population Density vs. Violent Crime', fontsize=20)
plt.legend(loc='best', frameon=True)

# save figure
plt.savefig('output/popdens_v_vcrime.png')

# show plot
plt.show()

# %%
scipy.stats.linregress(final_df['Violent Rate'], final_df['Population Density'].astype(float))
# Out:
# LinregressResult(slope=32089.882422386494, intercept=2372.4890877731423, rvalue=0.099123719872693861, pvalue=0.71493706184142525, stderr=86095.882615855458)

# %%
# Build scatter plot population density vs. Property Crime Rate
fig, ax = plt.subplots(figsize=(15, 10))

final_df['Population Density'] = round(final_df['Population Density'].astype(float), 2)

ax.scatter(final_df['Property Rate'], final_df['Population Density'],
           edgecolor="k", linewidths=1, marker="o", s=100, label=final_df['Locale'],
           c='c', alpha=0.8)

for i,text in enumerate(final_df['Locale']):
    ax.annotate(i, (final_df['Property Rate'][i]+0.001, final_df['Population Density'][i]+80))

# format graph 
sns.set_style('darkgrid')
plt.xlim([0, 0.25])
plt.ylim([0, 10500])

plt.xlabel('Per Capita Property Crime Rate', fontsize=16)
plt.ylabel('Population Density (per sq. Mile)', fontsize=16)
plt.title('Population Density vs. Property Crime', fontsize=20)
plt.legend(loc='best', frameon=True)

# save figure
plt.savefig('output/popdens_v_pcrime.png')

# show plot
plt.show()

# %%
scipy.stats.linregress(final_df['Property Rate'], final_df['Population Density'].astype(float))
# Out:
# LinregressResult(slope=2542.8805274141077, intercept=2449.501131256211, rvalue=0.056021116193063547, pvalue=0.83673786650732129, stderr=12112.327962146515)

# %%
# Build scatter plot for median age vs. walk score
fig, ax = plt.subplots(figsize=(15, 10))


ax.scatter(final_df['Walk Score'], final_df['Median Age'], color='c', edgecolor='black',
           linewidths=1, marker="o", s=100, label=final_df['Locale'], alpha=.8)


for i,text in enumerate(final_df['Locale']):
    ax.annotate(i, (final_df['Walk Score'][i]+0.1, final_df['Median Age'][i]+.1))


# Format graph
plt.xlabel('Walk Score', fontsize=16)
plt.ylabel('Median Age', fontsize=16)
plt.title('Median Age vs. Walk Score', fontsize=20)
plt.xlim(0,70)
sns.set_style('darkgrid')
plt.legend(loc='best', frameon=True)
plt.savefig('output/Median Age vs. Walk Score.png')


plt.show()

# %%
# Build scatter plot for median age vs. walk score
fig, ax = plt.subplots(figsize=(15, 10))

plt.scatter(final_df['Walk Score'], final_df['Median Household Income'], color='c',
            edgecolor='black', alpha=.8, linewidths=1, marker="o", s=100, label=final_df['Locale'])

for i,text in enumerate(final_df['Locale']):
    ax.annotate(i, (final_df['Walk Score'][i]+.6, final_df['Median Household Income'][i]+100))

# Format graph
plt.xlabel('Walk Score', fontsize=16)
plt.ylabel('Median Household Income', fontsize=16)
plt.title('Median Household Income vs. Walk Score', fontsize=20)
plt.xlim(0,70)
sns.set_style('darkgrid')
plt.legend(loc='best', frameon=True)

plt.savefig('output/Median Household Income vs. Walk Score.png')


plt.show()

# %%
# Add data to plot for violent crime totals.
violent = plt.scatter(final_df['Walk Score'],
                      final_df['Violent Rate'],
                      label='Violent', color='hotpink', alpha=.8, edgecolor='black')                    

# Add data to plot for property crime totals.
property = plt.scatter(final_df['Walk Score'],
                       final_df['Property Rate'],
                       label='Property', color='c', alpha=.8, edgecolor='black')

# Add a legend in the best location.
plt.legend(handles=[violent, property], loc='best', title='Crime Type', frameon=True)

# Add labels to the x- and y-axes; give the chart a title.
plt.xlabel('Walk Score')
plt.ylabel('Per Capita Crime Rate')
plt.title('Crime Rate vs. Walk Score')

# Set x and y limits.
plt.xlim(0, 70)
plt.ylim(-.01, .3)

# Set the grid background style.
sns.set_style('darkgrid')

# %%
# Save and display plot.
output_path = os.path.join('output', 'crime-rate-vs-walk-score.png')
plt.savefig(output_path, dpi=200)
plt.show()

# %% [markdown]
# **Observed Trend**: No relationship between walk score and rate of violent crime, nor rate of property crime. Highest crime rates in both categories occurred for the two locales with walk scores in the mid- to upper-thirties.

# %% [markdown]
# ## Correlations

# %%
# Violent Crime Rate vs. Walk Score
violent_corr = np.corrcoef(final_df['Walk Score'], final_df['Violent Rate'])

# Property Crime Rate vs. Walk Score
property_corr = np.corrcoef(final_df['Walk Score'], final_df['Property Rate'])

# Print results
print('Violent crime rates and property crime rates do not correlate with\
walk scores (r = '+str(violent_corr[0,1])+' and r = '+str(property_corr[0,1])+', \
respectively')
# Out:
# Violent crime rates and property crime rates do not correlate withwalk scores (r = 0.205869188145 and r = 0.2270467226, respectively

# %% [markdown]
# **Conclusion:** Violent crime rates and property crime rates do not correlate with walk scores.

# %%
# Read and df bulk walkscore.com data for method analysis
df = pd.read_csv('raw_data/walk and transit scores.csv')
df = df.drop('Unnamed: 0',axis=1)
df.head(5)
# Out:
#                           Area        lat        lon  walk score  \
# 0  Albemarle County, Virginia   37.971597 -78.678889         0.0
# 1  Albemarle County, Virginia   38.016123 -78.585680         0.0
# 2  Albemarle County, Virginia   37.915674 -78.559752         0.0
# 3  Albemarle County, Virginia   37.929954 -78.628748         0.0
# 4  Albemarle County, Virginia   38.083671 -78.626375         0.0
#
#    transit score
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
# Begin minor clean of dataframe to prepare for visualization
df.head()
df['Area'].unique()
# Out:
# array(['Albemarle County, Virginia ', 'Alexandria city, Virginia',
#        'Arlington County, Virginia', 'Chesapeake city, Virginia',
#        'Chesterfield County, Virginia', 'Fairfax County, Virginia',
#        'Hampton city, Virginia', 'Henrico County, Virginia',
#        'Loudoun County, Virginia', 'Newport News city, Virginia',
#        'Norfolk city, Virginia', 'Prince William County, Virginia',
#        'Richmond city, Virginia', 'Spotsylvania County, Virginia',
#        'Stafford County, Virginia', 'Virginia Beach city, Virginia'], dtype=object)

# %%
# Complete minor clean of dataframe to prepare for visualization
df['area_fixed'] = df.Area.str.replace(' Police Department' , '')
df['area_fixed'] = df.area_fixed.str.replace(' Sheriff Office' , '')
df['area_fixed'] = df.area_fixed.str.replace(' Police Dept' , '')
df['area_fixed'] = df.area_fixed.str.replace(' Bureau Of Police' , '')
df['area_fixed'] = df.area_fixed.str.replace(' Police Department' , '')
display(df.head())
display(df['area_fixed'].unique())
df.drop('Area',axis=1)
# Out:
#                           Area        lat        lon  walk score  \
# 0  Albemarle County, Virginia   37.971597 -78.678889         0.0
# 1  Albemarle County, Virginia   38.016123 -78.585680         0.0
# 2  Albemarle County, Virginia   37.915674 -78.559752         0.0
# 3  Albemarle County, Virginia   37.929954 -78.628748         0.0
# 4  Albemarle County, Virginia   38.083671 -78.626375         0.0
#
#    transit score                   area_fixed
# 0            NaN  Albemarle County, Virginia
# 1            NaN  Albemarle County, Virginia
# 2            NaN  Albemarle County, Virginia
# 3            NaN  Albemarle County, Virginia
# 4            NaN  Albemarle County, Virginia
# array(['Albemarle County, Virginia ', 'Alexandria city, Virginia',
#        'Arlington County, Virginia', 'Chesapeake city, Virginia',
#        'Chesterfield County, Virginia', 'Fairfax County, Virginia',
#        'Hampton city, Virginia', 'Henrico County, Virginia',
#        'Loudoun County, Virginia', 'Newport News city, Virginia',
#        'Norfolk city, Virginia', 'Prince William County, Virginia',
#        'Richmond city, Virginia', 'Spotsylvania County, Virginia',
#        'Stafford County, Virginia', 'Virginia Beach city, Virginia'], dtype=object)
#             lat        lon  walk score  transit score  \
# 0     37.971597 -78.678889         0.0            NaN
# 1     38.016123 -78.585680         0.0            NaN
# 2     37.915674 -78.559752         0.0            NaN
# 3     37.929954 -78.628748         0.0            NaN
# 4     38.083671 -78.626375         0.0            NaN
# 5     38.035243 -78.454920        51.0            NaN
# 6     38.094007 -78.681978         3.0            NaN
# 7     38.024995 -78.673217         0.0            NaN
# 8     38.022927 -78.677170         0.0            NaN
# 9     37.973150 -78.478986         0.0            NaN
# 10    38.111074 -78.558037         1.0            NaN
# 11    37.935556 -78.515316         5.0            NaN
# 12    37.957457 -78.588266         0.0            NaN
# 13    38.015132 -78.496581        50.0           36.0
# 14    38.028248 -78.557586         0.0            NaN
# 15    38.111856 -78.544757         1.0            NaN
# 16    38.007097 -78.539260         3.0            NaN
# 17    37.982010 -78.547400         0.0            NaN
# 18    38.039389 -78.429574         0.0            NaN
# 19    38.077215 -78.643546         0.0            NaN
# 20    37.954214 -78.545786         0.0            NaN
# 21    37.998029 -78.697855         0.0            NaN
# 22    37.986785 -78.437825         4.0            NaN
# 23    37.994630 -78.658888         0.0            NaN
# 24    38.065213 -78.437324         5.0            NaN
# 25    37.992684 -78.609215         0.0            NaN
# 26    37.999831 -78.581060         0.0            NaN
# 27    38.000926 -78.469032         3.0            NaN
# 28    38.047223 -78.502459        35.0           37.0
# 29    38.075839 -78.610287         0.0            NaN
# ...         ...        ...         ...            ...
# 1570  36.651323 -76.105615         0.0            0.0
# 1571  36.572737 -75.946549         2.0            0.0
# 1572  36.573435 -76.020424         0.0            0.0
# 1573  36.538208 -75.984142         3.0            NaN
# 1574  36.535817 -76.009485         0.0            NaN
# 1575  36.571846 -76.070158         0.0            0.0
# 1576  36.640859 -76.116318         0.0            0.0
# 1577  36.652853 -76.004286         0.0            0.0
# 1578  36.666110 -75.935917         2.0            0.0
# 1579  36.676862 -75.927382         0.0            0.0
# 1580  36.604840 -75.904158         0.0            0.0
# 1581  36.688696 -76.080096         0.0            0.0
# 1582  36.668503 -76.085837         0.0            0.0
# 1583  36.669183 -76.006640         0.0            0.0
# 1584  36.608763 -75.892232         0.0            0.0
# 1585  36.601038 -75.931120         0.0            0.0
# 1586  36.621443 -76.028191         0.0            0.0
# 1587  36.555235 -75.989931         0.0            0.0
# 1588  36.596567 -75.885372         4.0            0.0
# 1589  36.563007 -75.968234         5.0            0.0
# 1590  36.563368 -75.948182         1.0            0.0
# 1591  36.673106 -75.894558         0.0            0.0
# 1592  36.666387 -76.004826         0.0            0.0
# 1593  36.643055 -76.043819         0.0            0.0
# 1594  36.647484 -76.043598         0.0            0.0
# 1595  36.652291 -76.001030         0.0            0.0
# 1596  36.594131 -76.036048         0.0            0.0
# 1597  36.703864 -75.998800         1.0            0.0
# 1598  36.683731 -76.068852         0.0            0.0
# 1599  36.631551 -75.908705         0.0            0.0
#
#                          area_fixed
# 0       Albemarle County, Virginia
# 1       Albemarle County, Virginia
# 2       Albemarle County, Virginia
# 3       Albemarle County, Virginia
# 4       Albemarle County, Virginia
# 5       Albemarle County, Virginia
# 6       Albemarle County, Virginia
# 7       Albemarle County, Virginia
# 8       Albemarle County, Virginia
# 9       Albemarle County, Virginia
# 10      Albemarle County, Virginia
# 11      Albemarle County, Virginia
# 12      Albemarle County, Virginia
# 13      Albemarle County, Virginia
# 14      Albemarle County, Virginia
# 15      Albemarle County, Virginia
# 16      Albemarle County, Virginia
# 17      Albemarle County, Virginia
# 18      Albemarle County, Virginia
# 19      Albemarle County, Virginia
# 20      Albemarle County, Virginia
# 21      Albemarle County, Virginia
# 22      Albemarle County, Virginia
# 23      Albemarle County, Virginia
# 24      Albemarle County, Virginia
# 25      Albemarle County, Virginia
# 26      Albemarle County, Virginia
# 27      Albemarle County, Virginia
# 28      Albemarle County, Virginia
# 29      Albemarle County, Virginia
# ...                             ...
# 1570  Virginia Beach city, Virginia
# 1571  Virginia Beach city, Virginia
# 1572  Virginia Beach city, Virginia
# 1573  Virginia Beach city, Virginia
# 1574  Virginia Beach city, Virginia
# 1575  Virginia Beach city, Virginia
# 1576  Virginia Beach city, Virginia
# 1577  Virginia Beach city, Virginia
# 1578  Virginia Beach city, Virginia
# 1579  Virginia Beach city, Virginia
# 1580  Virginia Beach city, Virginia
# 1581  Virginia Beach city, Virginia
# 1582  Virginia Beach city, Virginia
# 1583  Virginia Beach city, Virginia
# 1584  Virginia Beach city, Virginia
# 1585  Virginia Beach city, Virginia
# 1586  Virginia Beach city, Virginia
# 1587  Virginia Beach city, Virginia
# 1588  Virginia Beach city, Virginia
# 1589  Virginia Beach city, Virginia
# 1590  Virginia Beach city, Virginia
# 1591  Virginia Beach city, Virginia
# 1592  Virginia Beach city, Virginia
# 1593  Virginia Beach city, Virginia
# 1594  Virginia Beach city, Virginia
# 1595  Virginia Beach city, Virginia
# 1596  Virginia Beach city, Virginia
# 1597  Virginia Beach city, Virginia
# 1598  Virginia Beach city, Virginia
# 1599  Virginia Beach city, Virginia
#
# [1600 rows x 5 columns]

# %%
# Build visual for bulk walkscore.com data to assist in explaining methodology

sns.set_style("darkgrid")
plt.subplots(figsize=(11,10))
ax = sns.swarmplot(x="area_fixed", y="walk score", data=df)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=90, fontsize=14)
plt.title('Walk Scores in Virginia Areas of Interest', size = 20)
plt.xlabel('Area',size = 15)
plt.ylabel('Walk Score',size = 15)
plt.savefig('output/Walk Scores in Virginia.png')
plt.show()

# %%
agewalkmodel = sm.OLS(final_df['Walk Score'], final_df['Median Age']).fit()
predictions = agewalkmodel.predict(final_df['Median Age']) # make the predictions by the model

# Print out the statistics
agewalkmodel.summary()
# Out:
# C:\Users\brbal\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\scipy\stats\stats.py:1334: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Walk Score   R-squared:                       0.561
# Model:                            OLS   Adj. R-squared:                  0.532
# Method:                 Least Squares   F-statistic:                     19.20
# Date:                Fri, 05 Jan 2018   Prob (F-statistic):           0.000536
# Time:                        12:23:53   Log-Likelihood:                -70.869
# No. Observations:                  16   AIC:                             143.7
# Df Residuals:                      15   BIC:                             144.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Median Age     0.6506      0.148      4.382      0.001       0.334       0.967
# ==============================================================================
# Omnibus:                        2.218   Durbin-Watson:                   1.776
# Prob(Omnibus):                  0.330   Jarque-Bera (JB):                1.467
# Skew:                           0.519   Prob(JB):                        0.480
# Kurtosis:                       1.941   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
incomewalkmodel = sm.OLS(final_df['Walk Score'], final_df['Median Household Income']).fit()
predictions = incomewalkmodel.predict(final_df['Median Household Income']) # make the predictions by the model

# Print out the statistics
incomewalkmodel.summary()
# Out:
# C:\Users\brbal\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\scipy\stats\stats.py:1334: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Walk Score   R-squared:                       0.523
# Model:                            OLS   Adj. R-squared:                  0.491
# Method:                 Least Squares   F-statistic:                     16.45
# Date:                Fri, 05 Jan 2018   Prob (F-statistic):            0.00103
# Time:                        12:23:53   Log-Likelihood:                -71.539
# No. Observations:                  16   AIC:                             145.1
# Df Residuals:                      15   BIC:                             145.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Median Household Income  5.882e-05   1.45e-05      4.056      0.001    2.79e-05    8.97e-05
# ==============================================================================
# Omnibus:                        2.443   Durbin-Watson:                   1.471
# Prob(Omnibus):                  0.295   Jarque-Bera (JB):                1.807
# Skew:                           0.787   Prob(JB):                        0.405
# Kurtosis:                       2.520   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
popwalkmodel = sm.OLS(final_df['Walk Score'], final_df['Population']).fit()
predictions = popwalkmodel.predict(final_df['Population']) # make the predictions by the model

# Print out the statistics
popwalkmodel.summary()
# Out:
# C:\Users\brbal\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\scipy\stats\stats.py:1334: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Walk Score   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.530
# Method:                 Least Squares   F-statistic:                     19.01
# Date:                Fri, 05 Jan 2018   Prob (F-statistic):           0.000560
# Time:                        12:23:53   Log-Likelihood:                -70.914
# No. Observations:                  16   AIC:                             143.8
# Df Residuals:                      15   BIC:                             144.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Population     0.0003   6.52e-05      4.360      0.001       0.000       0.000
# ==============================================================================
# Omnibus:                        4.615   Durbin-Watson:                   1.832
# Prob(Omnibus):                  0.099   Jarque-Bera (JB):                1.378
# Skew:                           0.034   Prob(JB):                        0.502
# Kurtosis:                       1.564   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
